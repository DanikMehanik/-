# %% [markdown]
# Это чтобы мы не путались. Сами знаечния инициализируются в функции __init__ (class DQN) и при вызове
#
# *in_size* = 6
#
# *hid_size* = 64
#
# *out_size* = 1
#
# *l_rate* = 0.001
#
# *gamma* = 0.99
#
# *epsilon* = 0.2
#
# *epsilon_decay* = 0.995
#
# *epsilon_min* = 0.05

# %%
pip install torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import copy
import random
from wellplan.builder import PlanBuilder, Plan, WellPlanContext
from wellplan.services.cost import CostFunction
from wellplan.services import ArpsDeclineProductionProfile
from wellplan.data.file.loader import ExcelWellLoader
import pandas as pd
import datetime
from wellplan.services.team_manager import DistanceTeamMovement
from datetime import timedelta

# %% [markdown]
# Загружаем таблички

# %%
#loader = ExcelWellLoader(file_path = r'C:\Users\Анна\Downloads\Sirius_GazpromNeft-main\well-plan-optimization-main\data\Ввод ЭБ 1+11 Обезлич_v3.xlsx')
loader = ExcelWellLoader(file_path = r'C:\Users\Анна\Downloads\Sirius_GazpromNeft-main\well-plan-optimization-main\data\Ввод ЭБ эксперимент.xlsx')
wells = loader.load()

production_profile = ArpsDeclineProductionProfile()

coordinates = pd.read_excel(
    r'C:\Users\Анна\Downloads\Sirius_GazpromNeft-main\well-plan-optimization-main\data\База перспективного ПФ (30.01.2025).xlsx',
    header = 0,
    names = ['cluster', 'x', 'y', 'z']
)

move = DistanceTeamMovement.from_dicts(coordinates.to_dict(orient='records'))

# %% [markdown]
# Класс модели

# %%
from wellplan.services.cost import BaseCapex, BaseOpex, NPV

# %%
from wellplan.services.production import ProductionProfile

# %%
capex = BaseCapex(
    build_cost_per_metr={
        "ГС+ГРП": 25300,
        "ННС+ГРП": 12900,
        "МЗС": 27300,
        "МЗС+ГРП": 28300,
        "ГС": 23300,
    },
    equipment_cost=2500000,
)

opex = BaseOpex(
    oil_cost_per_tone=109.9,
    water_cost_per_tone=48.6,
    repair_per_year=3093900,
    maintain_per_year=2336200,
)


npv = NPV(
    oil_price_per_tone=13896,
    project_start_date=datetime.datetime.now(),
    capex_cost=capex,
    opex_cost=opex,
    discount_rate=0.125,
)

# %%
class DQN(nn.Module, CostFunction): #зачем CostFunction?
    #инициализируем все переменные 
    def __init__(
        self,
        in_size: int = 6,
        hid_size: int = 64,
        out_size: int = 1,
        gamma: float = 0.99,
        l_rate: float = 0.001,
        npv: NPV = None,
        profiller = None
    ):
        
        super(DQN, self).__init__()

        self.l1 = nn.Linear(in_size, hid_size)   
        self.l2 = nn.Linear(hid_size, hid_size)     

        self.out = nn.Linear(hid_size, out_size)    
        
        self.npv = npv
        self.gamma = gamma
        self.profiller = profiller

        self.optimizer = optim.Adam(self.parameters(), lr = l_rate)
        self.criterion = nn.MSELoss()

    #определяем фичи и тензорим (перевод чисел в вид, интерпритируемый моделью)
    def a_s_tensor(self, state: Plan, action: WellPlanContext) -> torch.Tensor:
        features = [
            action.well.oil_rate,
            action.well.liq_rate,
            action.well.length,
            len(action.well.tasks), 
            len(state.well_plans), 
            state.total_profit(),
        ]

        return torch.Tensor(features) 

    #двигаемся по нейронке, передаём данные по слоям
    def forward(self, x):
        x = torch.relu(self.l1(x))
        x = torch.relu(self.l2(x))
        return self.out(x)


    #тензор экшн и стейт, переводим в батч (группа примеров, которую модель обрабатывает за один шаг) и получаем вес сочетания
    def compute(self, state: Plan, action: WellPlanContext) -> WellPlanContext:
        x = self.a_s_tensor(state, action).unsqueeze(0) 

        with torch.no_grad():
            action.cost = self.forward(x).item()
        
        return action
    
    #награды
    def update(self, state: Plan, action: WellPlanContext) -> None:
        state_tensor = self.a_s_tensor(state, action).unsqueeze(0)

        prev_npv = self.npv.compute(state, action)

        new_state = copy.deepcopy(state)
        new_state.add_context(action)

        #next_npv = self.npv.compute(new_state, action)

        reward = new_state.total_profit() - prev_npv

        reward_tensor = torch.tensor([reward]).unsqueeze(0)

        q_value = self.forward(state_tensor)

        loss = self.criterion(q_value, reward_tensor)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
from typing import Optional
from datetime import datetime
from loguru import logger
from wellplan.core.well import Well

from wellplan.core.team import TeamPool

from wellplan.services.risk_strategy import RiskStrategy
from wellplan.services.cost import CostFunction
from wellplan.services.infrastructure import Infrastructure, SimpleInfrastructure
from wellplan.services.team_manager import BaseTeamManager
from wellplan.services.production import ProductionProfile, LinearProductionProfile
from wellplan.services.constraint import ConstraintManager, Constraint
from wellplan.services.team_manager import TeamManager

# %% [markdown]
# Класс составления итогового плана

# %%
class DQN_go(PlanBuilder):
    #инициализируем приколы для обучения, саму модель
    def __init__(self, start, end, in_size, l_rate, epsilon, epsilon_decay, epsilon_min, npv, profiller):
        
        self.model = DQN(npv=npv, profiller=profiller)
        self.optimizer = optim.Adam(self.model.parameters(), lr = l_rate)

        super().__init__(
            start = start, 
            end = end,
            cost_function = self.model
        )

        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        
        
    #отправляем кандидатов в нейронку, на каждом кандидате сравниваем его с лучшим на данный момент (храним только инфу про лучшего)
    def _select_best_candidate(self, plan: Plan,candidates: list[WellPlanContext]) -> WellPlanContext:
        best_value = float('-inf')
        best_candidate = None

        if self.epsilon > random.random():
            return random.choice(candidates)

        for candidate in candidates:
            value = self.cost_function.compute(plan, candidate).cost

            if best_value < value:
                best_candidate = candidate
                best_value = value

        return best_candidate

    #сбор итогового плана
    def compile(
        self,
        wells: list[Well],
        manager: BaseTeamManager,
        risk_strategy: Optional[RiskStrategy] = None,
        keep_order: bool = False,
        cluster_ordered: bool = True,

    ) -> Plan:
        plan = Plan()
        self.remaining_wells = wells.copy()

        current_start = self.start

        while self.remaining_wells and current_start < self.end:
            candidates = self._build_contexts(manager, current_start)
            if not candidates:
                break

            candidates = self._filter_candidates(candidates, plan, risk_strategy, cluster_ordered)
            
            if not candidates:
                next_year = self._constraints.get_period_end(current_start.year)
                logger.info(f"No candidates for {current_start.year}, moving to {next_year or current_start.year+1}")
                
                current_start = datetime((next_year or current_start.year+1), 1, 1)
                continue


            best_candidate = self._select_best_candidate(
                plan, candidates
            )

            self.epsilon = max(self.epsilon * self.epsilon_decay, self.epsilon_min)

            logger.debug(f"Best candidate: {best_candidate.well.name}, cost: {best_candidate.cost}")
            manager.assign(best_candidate)

            self.remaining_wells.remove(best_candidate.well)

            if risk_strategy:
                risk_strategy.define_risk(best_candidate)
                
            self.cost_function.compute(plan, best_candidate)

            plan.add_context(best_candidate)

        return plan

# %% [markdown]
# Запуск обучения

# %%
agent = DQN_go(
    start = datetime.now(),
    end = datetime.now() + timedelta(25 * 365),
    in_size = 6,
    l_rate = 0.001, 
    epsilon = 1,
    epsilon_decay = 0.995,
    epsilon_min = 0.05,
    npv = npv,
    profiller = production_profile
)

plans = []

# %%
n_episods = 3000

results = {'episod': [], 'id': [], 'target_value': [], 'wells': []}

for episod in range(n_episods):
    team_pool = TeamPool()
    team_pool.add_teams(['ГС'], num_teams = 1)
    team_pool.add_teams(['ГРП'], num_teams = 1)

    manager = TeamManager(team_pool = team_pool)
    plan = agent.compile(wells = wells.copy(), manager = manager)

    wells_list = [str(context.well.name) for context in plan.well_plans]

    results['episod'].append(episod)
    results['id'].append(plan.id)
    results['target_value'].append(plan.total_profit())
    results['wells'].append(wells_list)

    plans.append(plan)
# Out:
# 2025-07-12 12:20:43.359 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:43.364 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -191.0658416748047
# 2025-07-12 12:20:43.368 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -199.3600311279297
# 2025-07-12 12:20:43.371 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -191.83299255371094
# 2025-07-12 12:20:43.373 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -200.7330322265625
# 2025-07-12 12:20:43.375 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -171.515869140625
# 2025-07-12 12:20:43.377 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.912353515625
# 2025-07-12 12:20:43.378 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -174.58184814453125
# 2025-07-12 12:20:43.383 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.387 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.390 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -176.3038330078125
# 2025-07-12 12:20:43.393 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.44151306152344
# 2025-07-12 12:20:43.397 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.90968322753906
# 2025-07-12 12:20:43.397 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.26344299316406
# 2025-07-12 12:20:43.408 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.0113067626953
# 2025-07-12 12:20:43.409 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -174.4878387451172
# 2025-07-12 12:20:43.413 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.420 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -195.55850219726562
# 2025-07-12 12:20:43.427 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.70018005371094
# 2025-07-12 12:20:43.432 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -191.7540740966797
# 2025-07-12 12:20:43.437 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.78968811035156
# 2025-07-12 12:20:43.440 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.27755737304688
# 2025-07-12 12:20:43.444 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -176.31739807128906
# 2025-07-12 12:20:43.447 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -174.2584991455078
# 2025-07-12 12:20:43.449 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:43.456 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.58282470703125
# 2025-07-12 12:20:43.459 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.58056640625
# 2025-07-12 12:20:43.462 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -179.93983459472656
# 2025-07-12 12:20:43.464 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.900146484375
# 2025-07-12 12:20:43.468 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.63243103027344
# 2025-07-12 12:20:43.471 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.11865234375
# 2025-07-12 12:20:43.472 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -187.48773193359375
# 2025-07-12 12:20:43.480 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:43.482 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -172.61708068847656
# 2025-07-12 12:20:43.491 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.29270935058594
# 2025-07-12 12:20:43.495 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -173.71238708496094
# 2025-07-12 12:20:43.499 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.8978271484375
# 2025-07-12 12:20:43.503 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.9311065673828
# 2025-07-12 12:20:43.506 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.32460021972656
# 2025-07-12 12:20:43.507 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -195.37184143066406
# 2025-07-12 12:20:43.512 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.515 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -172.8584747314453
# 2025-07-12 12:20:43.515 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -186.77288818359375
# 2025-07-12 12:20:43.523 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.7511749267578
# 2025-07-12 12:20:43.525 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.5442352294922
# 2025-07-12 12:20:43.527 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.67520141601562
# 2025-07-12 12:20:43.529 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.8552703857422
# 2025-07-12 12:20:43.530 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -174.5249481201172
# 2025-07-12 12:20:43.534 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.538 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -172.46836853027344
# 2025-07-12 12:20:43.541 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -194.31756591796875
# 2025-07-12 12:20:43.541 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.78038024902344
# 2025-07-12 12:20:43.546 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.92356872558594
# 2025-07-12 12:20:43.548 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.9535369873047
# 2025-07-12 12:20:43.551 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.146240234375
# 2025-07-12 12:20:43.551 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -187.5078582763672
# 2025-07-12 12:20:43.555 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -168.98593139648438
# 2025-07-12 12:20:43.558 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -172.9993438720703
# 2025-07-12 12:20:43.561 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.75131225585938
# 2025-07-12 12:20:43.565 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -173.17665100097656
# 2025-07-12 12:20:43.569 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.9247283935547
# 2025-07-12 12:20:43.572 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.62193298339844
# 2025-07-12 12:20:43.575 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.8428192138672
# 2025-07-12 12:20:43.576 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.7896270751953
# 2025-07-12 12:20:43.580 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.584 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.587 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.590 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:43.593 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -206.13270568847656
# 2025-07-12 12:20:43.595 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -200.6775360107422
# 2025-07-12 12:20:43.596 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.31532287597656
# 2025-07-12 12:20:43.598 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -195.36517333984375
# 2025-07-12 12:20:43.606 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:43.610 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.58282470703125
# 2025-07-12 12:20:43.616 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -186.77088928222656
# 2025-07-12 12:20:43.616 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.69056701660156
# 2025-07-12 12:20:43.622 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -201.30799865722656
# 2025-07-12 12:20:43.624 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.5406036376953
# 2025-07-12 12:20:43.625 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.52978515625
# 2025-07-12 12:20:43.627 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -195.3623809814453
# 2025-07-12 12:20:43.631 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.639 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -183.5906524658203
# 2025-07-12 12:20:43.642 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.84291076660156
# 2025-07-12 12:20:43.644 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.7457733154297
# 2025-07-12 12:20:43.647 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.24049377441406
# 2025-07-12 12:20:43.649 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.24362182617188
# 2025-07-12 12:20:43.651 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.12982177734375
# 2025-07-12 12:20:43.653 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -174.9430694580078
# 2025-07-12 12:20:43.656 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -180.03114318847656
# 2025-07-12 12:20:43.660 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -191.2863311767578
# 2025-07-12 12:20:43.663 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -196.0298614501953
# 2025-07-12 12:20:43.666 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -173.71493530273438
# 2025-07-12 12:20:43.668 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.82447814941406
# 2025-07-12 12:20:43.670 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.25006103515625
# 2025-07-12 12:20:43.672 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.1436767578125
# 2025-07-12 12:20:43.673 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -174.9532012939453
# 2025-07-12 12:20:43.677 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -168.98593139648438
# 2025-07-12 12:20:43.681 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.1744384765625
# 2025-07-12 12:20:43.683 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -186.92164611816406
# 2025-07-12 12:20:43.686 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -203.8053436279297
# 2025-07-12 12:20:43.688 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -200.95899963378906
# 2025-07-12 12:20:43.691 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.287109375
# 2025-07-12 12:20:43.691 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -176.79067993164062
# 2025-07-12 12:20:43.695 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -168.0397491455078
# 2025-07-12 12:20:43.698 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -187.48040771484375
# 2025-07-12 12:20:43.702 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.9736328125
# 2025-07-12 12:20:43.705 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -176.77088928222656
# 2025-07-12 12:20:43.709 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.1841583251953
# 2025-07-12 12:20:43.710 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -201.2049560546875
# 2025-07-12 12:20:43.712 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -180.0534210205078
# 2025-07-12 12:20:43.713 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.42697143554688
# 2025-07-12 12:20:43.714 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -201.008544921875
# 2025-07-12 12:20:43.717 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.723 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.726 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.729 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:43.731 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:43.731 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:43.731 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:43.737 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:43.740 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.745 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.750 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.752 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:43.755 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -201.43324279785156
# 2025-07-12 12:20:43.757 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.2138214111328
# 2025-07-12 12:20:43.757 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.9291534423828
# 2025-07-12 12:20:43.757 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.97996520996094
# 2025-07-12 12:20:43.764 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:43.768 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.58282470703125
# 2025-07-12 12:20:43.770 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.10047912597656
# 2025-07-12 12:20:43.772 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.7938690185547
# 2025-07-12 12:20:43.776 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.9109344482422
# 2025-07-12 12:20:43.778 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.36917114257812
# 2025-07-12 12:20:43.779 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.33839416503906
# 2025-07-12 12:20:43.780 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -195.38182067871094
# 2025-07-12 12:20:43.783 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.788 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.791 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.793 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:43.797 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:43.798 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:43.798 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.5214080810547
# 2025-07-12 12:20:43.798 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.79197692871094
# 2025-07-12 12:20:43.806 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.808 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -190.91709899902344
# 2025-07-12 12:20:43.812 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0207061767578
# 2025-07-12 12:20:43.814 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.17027282714844
# 2025-07-12 12:20:43.817 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74635314941406
# 2025-07-12 12:20:43.819 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21119689941406
# 2025-07-12 12:20:43.821 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.53028869628906
# 2025-07-12 12:20:43.822 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.79747009277344
# 2025-07-12 12:20:43.823 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.830 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -191.69134521484375
# 2025-07-12 12:20:43.833 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0394744873047
# 2025-07-12 12:20:43.833 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.5559844970703
# 2025-07-12 12:20:43.839 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.23622131347656
# 2025-07-12 12:20:43.841 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21214294433594
# 2025-07-12 12:20:43.842 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.95620727539062
# 2025-07-12 12:20:43.842 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99729919433594
# 2025-07-12 12:20:43.848 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.849 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.856 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.858 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -191.2174835205078
# 2025-07-12 12:20:43.860 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74171447753906
# 2025-07-12 12:20:43.862 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21649169921875
# 2025-07-12 12:20:43.864 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.4475555419922
# 2025-07-12 12:20:43.866 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -201.01307678222656
# 2025-07-12 12:20:43.873 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.878 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.883 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -176.3038330078125
# 2025-07-12 12:20:43.885 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -179.93960571289062
# 2025-07-12 12:20:43.889 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.9300537109375
# 2025-07-12 12:20:43.890 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21824645996094
# 2025-07-12 12:20:43.892 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.4182586669922
# 2025-07-12 12:20:43.894 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9950714111328
# 2025-07-12 12:20:43.899 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.902 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -190.91709899902344
# 2025-07-12 12:20:43.906 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0207061767578
# 2025-07-12 12:20:43.908 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -203.81809997558594
# 2025-07-12 12:20:43.912 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.2450408935547
# 2025-07-12 12:20:43.914 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.9880828857422
# 2025-07-12 12:20:43.916 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.37741088867188
# 2025-07-12 12:20:43.917 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.8447265625
# 2025-07-12 12:20:43.921 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.925 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -195.55850219726562
# 2025-07-12 12:20:43.929 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.13330078125
# 2025-07-12 12:20:43.931 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -191.51141357421875
# 2025-07-12 12:20:43.934 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.24208068847656
# 2025-07-12 12:20:43.934 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -181.10702514648438
# 2025-07-12 12:20:43.937 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.89723205566406
# 2025-07-12 12:20:43.939 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.82887268066406
# 2025-07-12 12:20:43.942 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.945 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.948 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:43.950 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:43.954 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:43.956 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:43.957 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:43.958 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:43.965 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.969 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:43.971 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -198.72372436523438
# 2025-07-12 12:20:43.973 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.21763610839844
# 2025-07-12 12:20:43.976 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.7629852294922
# 2025-07-12 12:20:43.979 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -181.1077880859375
# 2025-07-12 12:20:43.980 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.8914031982422
# 2025-07-12 12:20:43.982 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.8246612548828
# 2025-07-12 12:20:43.985 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:43.988 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -190.91709899902344
# 2025-07-12 12:20:43.993 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0207061767578
# 2025-07-12 12:20:43.995 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.17027282714844
# 2025-07-12 12:20:43.997 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74635314941406
# 2025-07-12 12:20:43.999 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21119689941406
# 2025-07-12 12:20:44.001 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -204.53028869628906
# 2025-07-12 12:20:44.003 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.79747009277344
# 2025-07-12 12:20:44.006 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -168.57496643066406
# 2025-07-12 12:20:44.010 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.56646728515625
# 2025-07-12 12:20:44.013 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9547576904297
# 2025-07-12 12:20:44.015 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.3103485107422
# 2025-07-12 12:20:44.015 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.9305419921875
# 2025-07-12 12:20:44.020 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21817016601562
# 2025-07-12 12:20:44.022 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41920471191406
# 2025-07-12 12:20:44.023 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99566650390625
# 2025-07-12 12:20:44.027 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:44.032 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.58282470703125
# 2025-07-12 12:20:44.035 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.58056640625
# 2025-07-12 12:20:44.038 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -179.93983459472656
# 2025-07-12 12:20:44.040 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92982482910156
# 2025-07-12 12:20:44.042 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -205.62132263183594
# 2025-07-12 12:20:44.045 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.85154724121094
# 2025-07-12 12:20:44.045 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.79595947265625
# 2025-07-12 12:20:44.050 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.054 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -172.8584747314453
# 2025-07-12 12:20:44.057 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.58253479003906
# 2025-07-12 12:20:44.060 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -179.9408721923828
# 2025-07-12 12:20:44.062 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92886352539062
# 2025-07-12 12:20:44.065 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21839904785156
# 2025-07-12 12:20:44.067 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41587829589844
# 2025-07-12 12:20:44.067 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9936065673828
# 2025-07-12 12:20:44.072 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -188.2260284423828
# 2025-07-12 12:20:44.076 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.9903564453125
# 2025-07-12 12:20:44.080 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -187.23838806152344
# 2025-07-12 12:20:44.082 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.6992645263672
# 2025-07-12 12:20:44.082 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.81703186035156
# 2025-07-12 12:20:44.088 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.24412536621094
# 2025-07-12 12:20:44.089 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -176.66912841796875
# 2025-07-12 12:20:44.091 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -201.05552673339844
# 2025-07-12 12:20:44.095 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.100 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.104 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.106 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.109 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -206.13270568847656
# 2025-07-12 12:20:44.110 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.22036743164062
# 2025-07-12 12:20:44.113 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.83554077148438
# 2025-07-12 12:20:44.115 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.7843780517578
# 2025-07-12 12:20:44.119 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.125 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.129 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.133 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.136 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.139 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.142 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.142 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.148 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.152 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -172.46836853027344
# 2025-07-12 12:20:44.156 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.5730743408203
# 2025-07-12 12:20:44.158 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31178283691406
# 2025-07-12 12:20:44.162 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92918395996094
# 2025-07-12 12:20:44.165 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21835327148438
# 2025-07-12 12:20:44.166 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41650390625
# 2025-07-12 12:20:44.168 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9939727783203
# 2025-07-12 12:20:44.172 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.175 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -191.69134521484375
# 2025-07-12 12:20:44.180 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -199.20066833496094
# 2025-07-12 12:20:44.183 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -180.079345703125
# 2025-07-12 12:20:44.186 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.24513244628906
# 2025-07-12 12:20:44.190 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.9830780029297
# 2025-07-12 12:20:44.192 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -190.37322998046875
# 2025-07-12 12:20:44.193 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -195.4069061279297
# 2025-07-12 12:20:44.197 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -188.2260284423828
# 2025-07-12 12:20:44.202 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.5721893310547
# 2025-07-12 12:20:44.208 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -169.77810668945312
# 2025-07-12 12:20:44.210 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.18849182128906
# 2025-07-12 12:20:44.214 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.7537841796875
# 2025-07-12 12:20:44.216 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -181.1017303466797
# 2025-07-12 12:20:44.218 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.9396514892578
# 2025-07-12 12:20:44.220 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.98709106445312
# 2025-07-12 12:20:44.225 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.230 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -172.46836853027344
# 2025-07-12 12:20:44.234 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.5730743408203
# 2025-07-12 12:20:44.236 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31178283691406
# 2025-07-12 12:20:44.241 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92918395996094
# 2025-07-12 12:20:44.242 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21835327148438
# 2025-07-12 12:20:44.244 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41650390625
# 2025-07-12 12:20:44.246 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9939727783203
# 2025-07-12 12:20:44.249 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -187.48040771484375
# 2025-07-12 12:20:44.254 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.9736328125
# 2025-07-12 12:20:44.259 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.02955627441406
# 2025-07-12 12:20:44.263 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.17494201660156
# 2025-07-12 12:20:44.265 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74659729003906
# 2025-07-12 12:20:44.267 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.2117462158203
# 2025-07-12 12:20:44.267 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.4178009033203
# 2025-07-12 12:20:44.270 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99478149414062
# 2025-07-12 12:20:44.275 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.279 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.283 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.284 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.288 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.290 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.292 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.295 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.301 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -192.01516723632812
# 2025-07-12 12:20:44.305 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -166.0752410888672
# 2025-07-12 12:20:44.310 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -187.3323516845703
# 2025-07-12 12:20:44.313 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -179.9845733642578
# 2025-07-12 12:20:44.316 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.24208068847656
# 2025-07-12 12:20:44.318 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -181.10711669921875
# 2025-07-12 12:20:44.321 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.89654541015625
# 2025-07-12 12:20:44.322 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.82839965820312
# 2025-07-12 12:20:44.324 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.330 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.334 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.336 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.340 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.341 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.341 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.345 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.349 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.355 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.359 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.362 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.365 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.90013122558594
# 2025-07-12 12:20:44.367 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21307373046875
# 2025-07-12 12:20:44.368 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.39535522460938
# 2025-07-12 12:20:44.368 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.98094177246094
# 2025-07-12 12:20:44.374 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.379 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.383 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.383 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.389 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.391 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -200.65914916992188
# 2025-07-12 12:20:44.393 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.95263671875
# 2025-07-12 12:20:44.394 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99510192871094
# 2025-07-12 12:20:44.400 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.405 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.410 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.413 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.417 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.419 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.422 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.423 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.427 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.430 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.430 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -194.30567932128906
# 2025-07-12 12:20:44.438 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.16287231445312
# 2025-07-12 12:20:44.440 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.7460174560547
# 2025-07-12 12:20:44.441 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21034240722656
# 2025-07-12 12:20:44.445 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.4407196044922
# 2025-07-12 12:20:44.447 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -201.00889587402344
# 2025-07-12 12:20:44.448 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.456 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.457 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.457 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.466 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.469 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.471 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.472 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.473 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.479 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -195.55850219726562
# 2025-07-12 12:20:44.483 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.13330078125
# 2025-07-12 12:20:44.486 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -191.51141357421875
# 2025-07-12 12:20:44.488 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.24208068847656
# 2025-07-12 12:20:44.488 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -181.10702514648438
# 2025-07-12 12:20:44.488 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.89723205566406
# 2025-07-12 12:20:44.488 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.82887268066406
# 2025-07-12 12:20:44.498 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.503 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.507 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.510 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.513 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.515 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.515 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.515 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.523 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.526 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.531 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.08016967773438
# 2025-07-12 12:20:44.535 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.17247009277344
# 2025-07-12 12:20:44.540 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74649047851562
# 2025-07-12 12:20:44.542 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21144104003906
# 2025-07-12 12:20:44.544 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.96762084960938
# 2025-07-12 12:20:44.546 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -201.00433349609375
# 2025-07-12 12:20:44.551 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.555 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -191.69134521484375
# 2025-07-12 12:20:44.558 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0394744873047
# 2025-07-12 12:20:44.561 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.5559844970703
# 2025-07-12 12:20:44.563 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.23622131347656
# 2025-07-12 12:20:44.566 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21214294433594
# 2025-07-12 12:20:44.566 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.95620727539062
# 2025-07-12 12:20:44.566 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99729919433594
# 2025-07-12 12:20:44.577 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.582 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.586 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.589 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.591 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.592 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.592 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.596 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.601 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.605 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.608 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.612 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.615 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.617 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.618 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.621 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.625 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -169.36460876464844
# 2025-07-12 12:20:44.630 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.58282470703125
# 2025-07-12 12:20:44.634 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.58056640625
# 2025-07-12 12:20:44.638 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -179.93983459472656
# 2025-07-12 12:20:44.640 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92982482910156
# 2025-07-12 12:20:44.642 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21829223632812
# 2025-07-12 12:20:44.642 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.4178009033203
# 2025-07-12 12:20:44.645 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.99478149414062
# 2025-07-12 12:20:44.649 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.653 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -172.46836853027344
# 2025-07-12 12:20:44.658 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.5730743408203
# 2025-07-12 12:20:44.660 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31178283691406
# 2025-07-12 12:20:44.665 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92918395996094
# 2025-07-12 12:20:44.668 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21835327148438
# 2025-07-12 12:20:44.670 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41650390625
# 2025-07-12 12:20:44.671 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9939727783203
# 2025-07-12 12:20:44.671 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -168.98593139648438
# 2025-07-12 12:20:44.679 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -165.57498168945312
# 2025-07-12 12:20:44.679 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -175.57119750976562
# 2025-07-12 12:20:44.679 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.310791015625
# 2025-07-12 12:20:44.689 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.93011474609375
# 2025-07-12 12:20:44.691 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21823120117188
# 2025-07-12 12:20:44.693 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41839599609375
# 2025-07-12 12:20:44.694 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9951171875
# 2025-07-12 12:20:44.699 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.703 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:44.708 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:44.708 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:44.715 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:44.715 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:44.715 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:44.720 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:44.725 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:44.729 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -190.91709899902344
# 2025-07-12 12:20:44.733 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.0207061767578
# ...
# 2025-07-12 12:20:47.416 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.421 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.425 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.428 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.431 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.434 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.434 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.438 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.443 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.448 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.456 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.461 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.467 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.469 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.471 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.473 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.478 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.482 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.486 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.491 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.496 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.501 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.505 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.508 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.516 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.524 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.531 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.537 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.542 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.546 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.548 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.549 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.554 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.559 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.566 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.572 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.578 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.581 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.583 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.585 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.592 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.597 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.600 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.606 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.609 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.611 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.613 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.615 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.620 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.625 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.631 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.635 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.638 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.641 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.641 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.641 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.649 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.657 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.662 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.665 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.669 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.670 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.673 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.674 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.679 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.684 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.687 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.690 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.693 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.697 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.699 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.700 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.705 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.709 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.714 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.717 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.720 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.722 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.725 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.726 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.732 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.736 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.740 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.744 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.746 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.750 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.750 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.756 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.762 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.765 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.773 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.773 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.783 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.785 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.788 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.789 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.796 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.800 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.806 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.810 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.816 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.820 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.825 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.828 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.836 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.842 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.851 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.856 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.862 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.867 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.870 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.872 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.877 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.883 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.889 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.894 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.899 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.902 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.903 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.905 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.913 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.919 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.927 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.932 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.933 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.938 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.940 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.940 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.947 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -192.01516723632812
# 2025-07-12 12:20:47.952 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -166.0752410888672
# 2025-07-12 12:20:47.956 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -176.1420440673828
# 2025-07-12 12:20:47.959 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -180.23387145996094
# 2025-07-12 12:20:47.962 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.74847412109375
# 2025-07-12 12:20:47.966 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -193.21841430664062
# 2025-07-12 12:20:47.968 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -198.8632049560547
# 2025-07-12 12:20:47.969 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -195.8043670654297
# 2025-07-12 12:20:47.972 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.976 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:47.980 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:47.983 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:47.985 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:47.987 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906
# 2025-07-12 12:20:47.990 | DEBUG    | __main__:compile:72 - Best candidate: 6743, cost: -199.41773986816406
# 2025-07-12 12:20:47.991 | DEBUG    | __main__:compile:72 - Best candidate: 1705, cost: -200.9947509765625
# 2025-07-12 12:20:47.995 | DEBUG    | __main__:compile:72 - Best candidate: 5611, cost: -162.1707000732422
# 2025-07-12 12:20:47.999 | DEBUG    | __main__:compile:72 - Best candidate: 2008, cost: -172.0335235595703
# 2025-07-12 12:20:48.001 | DEBUG    | __main__:compile:72 - Best candidate: 6465, cost: -175.9562530517578
# 2025-07-12 12:20:48.007 | DEBUG    | __main__:compile:72 - Best candidate: 658, cost: -180.31112670898438
# 2025-07-12 12:20:48.009 | DEBUG    | __main__:compile:72 - Best candidate: 4528, cost: -192.92979431152344
# 2025-07-12 12:20:48.011 | DEBUG    | __main__:compile:72 - Best candidate: 6912, cost: -200.21827697753906

# %%
df = pd.DataFrame(results)

# %%
df = df.sort_values(by='target_value')[::-1].reset_index()
df

# %%
print(*plans)
